# %% [markdown]
# Import Required Libraries

# %%
# !pip install seaborn plotly
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

sns.set_style("whitegrid")

# %% [markdown]
# Load Dataset

# %%
import os
print(os.getcwd())
# Out:
# /teamspace/studios/this_studio/Eda_Project

# %%
import os

os.chdir("/teamspace/studios/this_studio/Eda_Project")

# %%
os.listdir()
# Out:
# ['iframe_figures', 'Eda_Dashboard.ipynb', 'train.csv', 'app.py']

# %%
import os

for root, dirs, files in os.walk("/"):
    if "train.csv" in files:
        print(os.path.join(root, "train.csv"))
# Out:
# /home/zeus/content/Eda_Project/train.csv
# /teamspace/studios/this_studio/Eda_Project/train.csv

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# Check dataset information.

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# Convert Order Date to datetime.

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)

df["Year"] = df["Order Date"].dt.year
df["Month"] = df["Order Date"].dt.month

# %%
df["Order Date"].head()
# Out:
# 0   2017-11-08
# 1   2017-11-08
# 2   2017-06-12
# 3   2016-10-11
# 4   2016-10-11
# Name: Order Date, dtype: datetime64[ns]

# %% [markdown]
# KPI Cards
#
# Calculate the key metrics.

# %%
total_sales = df['Sales'].sum()
total_orders = df['Order ID'].nunique()
avg_sales_per_order = df['Sales'].mean()

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %% [markdown]
# Display KPI dashboard.

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Indicator(
    mode="number",
    value=total_sales,
    title={"text": "Total Sales"},
    domain={'x':[0,0.33],'y':[0,1]}
))

fig.add_trace(go.Indicator(
    mode="number",
    value=avg_sales_per_order,
    title={"text": "Avg Sales per Order"},
    domain={'x':[0.33,0.66],'y':[0,1]}
))

fig.add_trace(go.Indicator(
    mode="number",
    value=total_orders,
    title={"text": "Total Orders"},
    domain={'x':[0.66,1],'y':[0,1]}
))

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_16.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Time Series Trend (Monthly Sales)

# %% [markdown]
# monthly_sales = df.groupby('Month')['Sales'].sum().reset_index()
# monthly_sales['Month'] = monthly_sales['Month'].astype(str)

# %% [markdown]
# Plot trend.

# %%
monthly_sales = df.groupby(df["Order Date"].dt.to_period("M"))["Sales"].sum().reset_index()

monthly_sales["Month"] = monthly_sales["Order Date"].astype(str)

monthly_sales.head()
# Out:
#   Order Date      Sales    Month
# 0    2015-01  14205.707  2015-01
# 1    2015-02   4519.892  2015-02
# 2    2015-03  55205.797  2015-03
# 3    2015-04  27906.855  2015-04
# 4    2015-05  23644.303  2015-05

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %%
fig = px.line(
    monthly_sales,
    x="Month",
    y="Sales",
    title="Monthly Sales Trend",
    markers=True
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Geographic View (Sales by Region)

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index()

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %% [markdown]
# Bar chart.

# %%
fig = px.bar(
    region_sales,
    x="Region",
    y="Sales",
    color="Region",
    title="Sales by Region"
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Product Analysis (Top 10 Sub-Categories)

# %%
sub_sales = df.groupby('Sub-Category')[['Sales']].sum().reset_index()

top10 = sub_sales.sort_values(
    by='Sales',
    ascending=False
).head(10)

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %% [markdown]
# Visualization.

# %%
fig = px.bar(
    top10,
    x='Sub-Category',
    y='Sales',
   
    title="Top 10 Sub-Categories by Sales and Profit"
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Interactive Filters (Category / Region / Year)

# %% [markdown]
# Example: Category filter.

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv("train.csv")

# convert date column
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)

# create Year column
df["Year"] = df["Order Date"].dt.year

fig = px.bar(
    df,
    x="Category",
    y="Sales",
    color="Region",
    facet_col="Year",
    title="Sales Distribution by Category, Region and Year"
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pip install streamlit plotly pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Page config
st.set_page_config(page_title="Superstore Dashboard", layout="wide")

st.title("📊 Superstore Sales EDA Dashboard")

# Load dataset
df = pd.read_csv("train.csv")

df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)

# -----------------------------
# Sidebar Filters
# -----------------------------

st.sidebar.header("Filters")

category = st.sidebar.multiselect(
    "Select Category",
    options=df["Category"].unique(),
    default=df["Category"].unique()
)

region = st.sidebar.multiselect(
    "Select Region",
    options=df["Region"].unique(),
    default=df["Region"].unique()
)

df = df[(df["Category"].isin(category)) & (df["Region"].isin(region))]

# -----------------------------
# KPI Cards
# -----------------------------

total_sales = df["Sales"].sum()
total_orders = df["Order ID"].nunique()
avg_sales = df["Sales"].mean()

col1, col2, col3 = st.columns(3)

col1.metric("Total Sales", f"${total_sales:,.0f}")
col2.metric("Avg Sales per Order", f"${avg_sales:,.2f}")
col3.metric("Total Orders", total_orders)

# -----------------------------
# Time Series Trend
# -----------------------------

monthly_sales = df.groupby(df["Order Date"].dt.to_period("M"))["Sales"].sum().reset_index()
monthly_sales["Month"] = monthly_sales["Order Date"].astype(str)

fig1 = px.line(
    monthly_sales,
    x="Month",
    y="Sales",
    title="Monthly Sales Trend",
    markers=True
)

st.plotly_chart(fig1, use_container_width=True)

# -----------------------------
# Geographic View
# -----------------------------

region_sales = df.groupby("Region")["Sales"].sum().reset_index()

fig2 = px.bar(
    region_sales,
    x="Region",
    y="Sales",
    color="Region",
    title="Sales by Region"
)

st.plotly_chart(fig2, use_container_width=True)

# -----------------------------
# Product Analysis
# -----------------------------

subcat_sales = df.groupby("Sub-Category")["Sales"].sum().reset_index()

top10 = subcat_sales.sort_values(by="Sales", ascending=False).head(10)

fig3 = px.bar(
    top10,
    x="Sub-Category",
    y="Sales",
    title="Top 10 Sub-Categories by Sales",
    color="Sales"
)

st.plotly_chart(fig3, use_container_width=True)
# Out:
# 2026-03-15 07:25:50.201 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 07:25:50.202 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 07:25:50.457
# ...
#   command:
#
#     streamlit run /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-03-15 07:25:50.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 07:25:50.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 07:25:50.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
